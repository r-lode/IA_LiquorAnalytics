# %% [markdown]
# Now that we have finally preprocessed all of our data, it is time to load everything into our database. Because our dataset is rather large, I made the choice not to store everything in a single table, but rather store it based on the yearly data as we have been doing.

# %%
import pandas as pd
import glob
import mysql.connector

# %%
#get version 4 files
files_list = glob.glob('V4*.csv')

#read files into a dictionary of dataframes
data_frames = {file: pd.read_csv(file) for file in files_list}

# %% [markdown]
# Now we have to setup the connection to the mysql database and load in the data. Here, the data loading into the MySQL Database was separated into two cycles to avoid crashing the kernel

# %%
#connect to mysql server
connection = mysql.connector.connect(
    host="host",
    user="root",
    password="not_my_pass",
    database="mysql_database"
)

#cursor to execute SQL commmands
cursor = connection.cursor()

#get range of years to insert into database
#NOTE putting the full range here was liable to crash the kernel
year_range = range(2012, 2019)


for year in year_range:
    #get dataframe from dictionary based on year
    dataframe = data_frames[f'V4_Iowa_Liquor_Data_{year}.csv']


    #write query to create table in mysql based on year
    #NOTE: you CANNOT run this directly in the cursor.create command
    create_table_query = f''' CREATE TABLE IF NOT EXISTS liquor_sales_{year} (
            id INT AUTO_INCREMENT PRIMARY KEY,
            Date DATE,
            Store_Number INT,
            Store_Name VARCHAR(100),
            Address VARCHAR(255),
            City VARCHAR(100),
            Zip_Code INT,
            Store_Location VARCHAR(255),
            County_Number FLOAT,
            County VARCHAR(100),
            Category FLOAT,
            Category_Name VARCHAR(255),
            Vendor_Number FLOAT,
            Vendor_Name VARCHAR(255),
            Item_Number INT,
            Item_Description VARCHAR(255),
            Pack INT,
            Bottle_Volume_ml INT,
            State_Bottle_Cost FLOAT,
            State_Bottle_Retail FLOAT,
            Bottles_Sold INT,
            Sale_Dollars FLOAT,
            Volume_Sold_Liters FLOAT,
            Volume_Sold_Gallons FLOAT,
            Longitude FLOAT,
            Latitude FLOAT,
            Imports INT,
            Vodka INT,
            Whisky INT,
            Rum INT,
            Liqueur INT,
            Tequila INT,
            Gin INT,
            Brandy INT,
            Schnapps INT,
            Scotch INT,
            Specialty INT,
            Special_Order INT
        )'''





    #create liquor table using formatted string
    cursor.execute(create_table_query)

    #define the MySQL insertion query
    insert_query = f'''
        INSERT INTO liquor_sales_{year} (
            Date, Store_Number, Store_Name, Address, City, Zip_Code,
            Store_Location, County_Number, County, Category, Category_Name,
            Vendor_Number, Vendor_Name, Item_Number, Item_Description,
            Pack, Bottle_Volume_ml, State_Bottle_Cost, State_Bottle_Retail,
            Bottles_Sold, Sale_Dollars, Volume_Sold_Liters, Volume_Sold_Gallons,
            Longitude, Latitude, Imports, Vodka, Whisky, Rum, Liqueur,
            Tequila, Gin, Brandy, Schnapps, Scotch, Specialty, Special_Order
        )
        VALUES (
            # %s, %s, %s, %s, %s, %s,
            # %s, %s, %s, %s, %s,
            # %s, %s, %s, %s,
            # %s, %s, %s, %s,
            # %s, %s, %s, %s,
            # %s, %s, %s, %s, %s, %s, %s,
            # %s, %s, %s, %s, %s, %s, %s
        )
    '''



    #convert 'Date' column to datetime and then to MySQL suitable format
    #NOTE: date must be in .strftime format to be useable in MySQL
    dataframe['Date'] = pd.to_datetime(dataframe['Date'], errors='coerce')
    dataframe['Date'] = dataframe['Date'].dt.strftime('%Y-%m-%d')

    #gather rows to be inserted into database
    data_tuples = [tuple(row) for row in dataframe.to_numpy()]

    #define a chunk size to insert tuples into database
    #NOTE: Not doing this will crash kernel
    chunk_size = 10000  # Adjust this as needed
    total_rows = len(data_tuples)
    inserted_rows = 0

    #loop to insert data into database
    for i in range(0, total_rows, chunk_size):
        chunk = data_tuples[i:i + chunk_size]
        cursor.executemany(insert_query, chunk)
        inserted_rows += len(chunk)
        print(f"Inserted {inserted_rows} out of {total_rows} rows for DataFrame V4_Iowa_Liquor_Data_{year}.csv.")

#commit the changes and close the connection
connection.commit()
connection.close()
# Out:
# Inserted 10000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 20000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 30000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 40000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 50000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 60000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 70000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 80000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 90000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 100000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 110000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 120000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 130000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 140000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 150000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 160000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 170000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 180000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 190000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 200000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 210000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 220000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 230000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 240000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 250000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 260000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 270000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 280000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 290000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 300000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 310000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 320000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 330000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 340000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 350000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 360000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 370000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 380000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 390000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 400000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 410000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 420000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 430000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 440000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 450000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 460000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 470000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 480000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 490000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 500000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 510000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 520000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 530000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 540000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 550000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 560000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 570000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 580000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 590000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 600000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 610000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 620000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 630000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 640000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 650000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 660000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 670000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 680000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 690000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 700000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 710000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 720000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 730000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 740000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 750000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 760000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 770000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 780000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 790000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 800000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 810000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 820000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 830000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 840000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 850000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 860000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 870000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 880000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 890000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 900000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 910000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 920000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 930000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 940000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 950000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 960000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 970000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 980000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 990000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1000000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1010000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1020000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1030000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1040000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1050000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1060000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1070000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1080000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1090000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1100000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1110000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1120000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1130000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1140000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1150000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1160000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1170000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1180000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1190000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1200000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1210000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1220000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1230000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1240000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1250000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1260000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1270000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1280000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1290000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1300000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1310000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1320000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1330000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1340000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1350000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1360000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1370000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1380000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1390000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1400000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1410000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1420000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1430000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1440000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1450000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1460000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1470000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1480000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1490000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1500000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1510000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1520000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1530000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1540000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1550000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1560000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1570000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1580000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1590000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1600000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1610000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1620000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1630000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1640000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1650000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1660000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1670000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1680000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1690000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1700000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1710000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1720000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1730000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1740000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1750000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1760000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1770000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1780000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1790000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1800000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1810000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1820000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1830000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1840000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1850000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1860000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1870000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1880000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1890000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1900000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1910000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1920000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1930000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1940000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1950000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1960000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1970000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1980000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 1990000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2000000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2010000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2020000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2030000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2040000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2050000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2060000 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 2066511 out of 2066511 rows for DataFrame V4_Iowa_Liquor_Data_2012.csv.
# Inserted 10000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 20000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 30000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 40000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 50000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 60000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 70000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 80000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 90000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 100000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 110000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 120000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 130000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 140000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 150000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 160000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 170000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 180000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 190000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 200000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 210000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 220000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 230000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 240000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 250000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 260000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 270000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 280000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 290000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 300000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 310000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 320000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 330000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 340000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 350000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 360000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 370000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 380000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 390000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 400000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 410000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 420000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 430000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 440000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 450000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 460000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 470000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 480000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 490000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted 500000 out of 2052827 rows for DataFrame V4_Iowa_Liquor_Data_2013.csv.
# Inserted
 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 460000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 470000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 480000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 490000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 500000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 510000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 520000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 530000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 540000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 550000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 560000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 570000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 580000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 590000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 600000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 610000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 620000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 630000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 640000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 650000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 660000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 670000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 680000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 690000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 700000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 710000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 720000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 730000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 740000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 750000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 760000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 770000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 780000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 790000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 800000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 810000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 820000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 830000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 840000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 850000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 860000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 870000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 880000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 890000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 900000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 910000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 920000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 930000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 940000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 950000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 960000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 970000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 980000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 990000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1000000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1010000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1020000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1030000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1040000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1050000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1060000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1070000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1080000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1090000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1100000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1110000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1120000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1130000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1140000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1150000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1160000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1170000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1180000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1190000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1200000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1210000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1220000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1230000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1240000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1250000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1260000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1270000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1280000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1290000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1300000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1310000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1320000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1330000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1340000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1350000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1360000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1370000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1380000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1390000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1400000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1410000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1420000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1430000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1440000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1450000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1460000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1470000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1480000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1490000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1500000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1510000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1520000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1530000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1540000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1550000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1560000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1570000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1580000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1590000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1600000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1610000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1620000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1630000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1640000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1650000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1660000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1670000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1680000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1690000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1700000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1710000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1720000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1730000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1740000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1750000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1760000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1770000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1780000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1790000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1800000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1810000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1820000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1830000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1840000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1850000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1860000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1870000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1880000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1890000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1900000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1910000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1920000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1930000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1940000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1950000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1960000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1970000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1980000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 1990000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2000000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2010000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2020000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2030000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2040000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2050000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2060000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2070000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2080000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2090000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2100000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2110000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2120000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2130000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2140000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2150000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2160000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2170000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2180000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2190000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2200000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2210000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2220000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2230000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2240000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2250000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2260000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2270000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2280000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2290000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2300000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2310000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2320000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2330000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2340000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2350000 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.
# Inserted 2350331 out of 2350331 rows for DataFrame V4_Iowa_Liquor_Data_2018.csv.

# %%
#connect to mysql server
connection = mysql.connector.connect(
    host="host",
    user="root",
    password="not_my_pass",
    database="mysql_database"
)

#cursor to execute SQL commmands
cursor = connection.cursor()

#get range of years to insert into database
#NOTE putting the full range here was liable to crash the kernel
year_range = range(2019, 2024)


for year in year_range:
    #get dataframe from dictionary based on year
    dataframe = data_frames[f'V4_Iowa_Liquor_Data_{year}.csv']


    #write query to create table in mysql based on year
    #NOTE: you CANNOT run this directly in the cursor.create command
    create_table_query = f''' CREATE TABLE IF NOT EXISTS liquor_sales_{year} (
            id INT AUTO_INCREMENT PRIMARY KEY,
            Date DATE,
            Store_Number INT,
            Store_Name VARCHAR(100),
            Address VARCHAR(255),
            City VARCHAR(100),
            Zip_Code INT,
            Store_Location VARCHAR(255),
            County_Number FLOAT,
            County VARCHAR(100),
            Category FLOAT,
            Category_Name VARCHAR(255),
            Vendor_Number FLOAT,
            Vendor_Name VARCHAR(255),
            Item_Number INT,
            Item_Description VARCHAR(255),
            Pack INT,
            Bottle_Volume_ml INT,
            State_Bottle_Cost FLOAT,
            State_Bottle_Retail FLOAT,
            Bottles_Sold INT,
            Sale_Dollars FLOAT,
            Volume_Sold_Liters FLOAT,
            Volume_Sold_Gallons FLOAT,
            Longitude FLOAT,
            Latitude FLOAT,
            Imports INT,
            Vodka INT,
            Whisky INT,
            Rum INT,
            Liqueur INT,
            Tequila INT,
            Gin INT,
            Brandy INT,
            Schnapps INT,
            Scotch INT,
            Specialty INT,
            Special_Order INT
        )'''





    #create liquor table using formatted string
    cursor.execute(create_table_query)

    #define the MySQL insertion query
    insert_query = f'''
        INSERT INTO liquor_sales_{year} (
            Date, Store_Number, Store_Name, Address, City, Zip_Code,
            Store_Location, County_Number, County, Category, Category_Name,
            Vendor_Number, Vendor_Name, Item_Number, Item_Description,
            Pack, Bottle_Volume_ml, State_Bottle_Cost, State_Bottle_Retail,
            Bottles_Sold, Sale_Dollars, Volume_Sold_Liters, Volume_Sold_Gallons,
            Longitude, Latitude, Imports, Vodka, Whisky, Rum, Liqueur,
            Tequila, Gin, Brandy, Schnapps, Scotch, Specialty, Special_Order
        )
        VALUES (
            # %s, %s, %s, %s, %s, %s,
            # %s, %s, %s, %s, %s,
            # %s, %s, %s, %s,
            # %s, %s, %s, %s,
            # %s, %s, %s, %s,
            # %s, %s, %s, %s, %s, %s, %s,
            # %s, %s, %s, %s, %s, %s, %s
        )
    '''



    #convert 'Date' column to datetime and then to MySQL suitable format
    #NOTE: date must be in .strftime format to be useable in MySQL
    dataframe['Date'] = pd.to_datetime(dataframe['Date'], errors='coerce')
    dataframe['Date'] = dataframe['Date'].dt.strftime('%Y-%m-%d')

    #gather rows to be inserted into database
    data_tuples = [tuple(row) for row in dataframe.to_numpy()]

    #define a chunk size to insert tuples into database
    #NOTE: Not doing this will crash kernel
    chunk_size = 10000  # Adjust this as needed
    total_rows = len(data_tuples)
    inserted_rows = 0

    #loop to insert data into database
    for i in range(0, total_rows, chunk_size):
        chunk = data_tuples[i:i + chunk_size]
        cursor.executemany(insert_query, chunk)
        inserted_rows += len(chunk)
        print(f"Inserted {inserted_rows} out of {total_rows} rows for DataFrame V4_Iowa_Liquor_Data_{year}.csv.")

#commit the changes and close the connection
connection.commit()
connection.close()
# Out:
# Inserted 10000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 20000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 30000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 40000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 50000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 60000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 70000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 80000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 90000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 100000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 110000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 120000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 130000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 140000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 150000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 160000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 170000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 180000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 190000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 200000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 210000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 220000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 230000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 240000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 250000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 260000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 270000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 280000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 290000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 300000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 310000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 320000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 330000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 340000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 350000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 360000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 370000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 380000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 390000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 400000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 410000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 420000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 430000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 440000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 450000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 460000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 470000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 480000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 490000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 500000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 510000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 520000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 530000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 540000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 550000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 560000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 570000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 580000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 590000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 600000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 610000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 620000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 630000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 640000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 650000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 660000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 670000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 680000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 690000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 700000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 710000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 720000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 730000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 740000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 750000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 760000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 770000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 780000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 790000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 800000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 810000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 820000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 830000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 840000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 850000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 860000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 870000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 880000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 890000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 900000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 910000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 920000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 930000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 940000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 950000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 960000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 970000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 980000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 990000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1000000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1010000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1020000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1030000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1040000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1050000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1060000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1070000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1080000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1090000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1100000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1110000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1120000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1130000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1140000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1150000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1160000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1170000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1180000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1190000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1200000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1210000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1220000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1230000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1240000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1250000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1260000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1270000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1280000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 1290000 out of 2371873 rows for DataFrame V4_Iowa_Liquor_Data_2019.csv.
# Inserted 